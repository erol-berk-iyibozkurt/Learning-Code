# %% [markdown]
# Alıştırma yapmak için bu defteri kullanacağım. Bu defter sayesinde bütün alıştırmalarım bir yerde toplanmış olacak.

# %% [markdown]
# # Alıştırma 1 | Say my name in greeting
# **Amaç:** İsime göre selamlaşma

# %% [markdown]
# 1. Seçenek - ismi değişken olarak karşı tarafa girdiyi oluşturuyor
# ```

# %%
name = input("Enter your name: ")
print("Hello " + name)

# Output:
# Enter your name: James
# James
# Out:
# Enter your name: Berk
# Hello Berk

# %% [markdown]
# 2. Seçenek - Var olan isim üzerinden fonksiyon şeklinde veriliyor

# %%
def greeting(name):
  print('Hi '+ name)
greeting('Deniz')
# Out:
# Hi Deniz

# %% [markdown]
# #Alıştırma 2 | guess my favourite number

# %%
my_favourite_number = 15
predicted_number = int(input("Guess my favourite number! Your prediction is "))
if predicted_number < 15:
  print("My favourite number is bigger than ", predicted_number)
elif predicted_number == my_favourite_number:
  print("You guessed my favourite number. Congratulations :)")
else:
  print("My favourite number is smaller than" + predicted_number)
# Out:
# Guess my favourite number! Your prediction is 5
# My favourite number is bigger than  5

# %%
import random
predicted_number = random.randint(0,50)
my_favourite_number = 15
if predicted_number < 15:
  print("My favourite number is bigger than ", predicted_number)
elif predicted_number == my_favourite_number:
  print("My favourite number is 15. You guessed my favourite number. Congratulations :)")
else:
  print("My favourite number is smaller than", predicted_number)
# Out:
# My favourite number is smaller than 46

# %% [markdown]
# # Word List to learn terms

# %%
abhängen = "von + Dativ"
list("abhängen von + Dativ")
print(abhängen)
# Out:
# von + Dativ

# %% [markdown]
# Exerecise section 2

# %%
person1="Amir"
person2="Elena"
names=[person1,person2]
greeting="Hello " + person2 +"!"
print(greeting)

his_age = 20
his_height = 1.80
his_hometown = "Iran"
print("I am coming from", his_hometown +".", "I'm", his_age, "years old and my height is", his_height)
# Out:
# Hello Elena!
# I am coming from Iran. I'm 20 years old and my height is 1.8

# %%
name1=input("Hi! What's your name? ") #Person 1
print('Hello',name1, "Nice to meet you.") # Person 1
name2=input("What is yours? ") # Person 1
print("Tell me about yourself.")
print("")
# Out:
# Hi! What's your name?Erol
# Hello Erol Nice to meet you.
# What is yours?Amir

# %%
en_sevdiğim_yemekler_ve_yerler = ["Eskişehir","Ankara","İstanbul","İzmir","Bursa","Kebap","Menemen","Mantı", "Gözleme","Börek"]
en_sevdiğim_yemekler = en_sevdiğim_yemekler_ve_yerler[5:]
en_sevdiğim_yerler = en_sevdiğim_yemekler_ve_yerler[:5]
print(en_sevdiğim_yemekler)
print(en_sevdiğim_yerler)
# Out:
# ['Kebap', 'Menemen', 'Mantı', 'Gözleme', 'Börek']
# ['Eskişehir', 'Ankara', 'İstanbul', 'İzmir', 'Bursa']

# %%
import random
a = random.randint(0,4)
b = random.randint(0,4)

rastgele_yemek = en_sevdiğim_yemekler[a]
rastgele_yer = en_sevdiğim_yerler[b]
print(rastgele_yemek)
print(rastgele_yer)
# Out:
# Mantı
# Bursa

# %%
favourite_places_foods = ["Paris", "Milan", "Barcelona", "Berlin", "Vegas", "Croissant", "Pasta", "Pizza", "Hamburger", "Steak"]
#Create two separate lists for places and foods using the list slicing technique

favourite_places = favourite_places_foods[0:5] #select all the places (Another option [:5])
favourite_food = favourite_places_foods[5:10] #select all the foods (Another option [5:])

#Select the first and last three from place and food lists
first_three_places=favourite_places[0:3]
last_three_foods =favourite_food[2:5]

#Print both lists
print(first_three_places)
print(last_three_foods)

#Please import the random module and generate two random numbers between 0 and 2
import random
a = random.randint(0,2)
b = random.randint(0,2)

#Use the generated numbers as indexes of randomely chosen items from place and food lists

meeting_place = first_three_places[a]
meeting_food = last_three_foods[b]
print(meeting_place)
print(meeting_food)
# Out:
# ['Paris', 'Milan', 'Barcelona']
# ['Pizza', 'Hamburger', 'Steak']
# Milan
# Pizza

# %% [markdown]
# # Tek Çift sayı Tespit Etme

# %%
sayi = input("Herhangi bir sayı giriniz.")
sayi = int(sayi)
if sayi % 2 == 0:
  print (sayi, "çift sayıdır.")
else:
  print(str(sayi), "tek sayıdır.")
# Out:
# Herhangi bir sayı giriniz.18
# 18 çift sayıdır.
