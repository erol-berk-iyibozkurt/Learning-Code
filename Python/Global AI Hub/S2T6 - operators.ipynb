# %%
print(2 + 5)
# Out:
# 7

# %% [markdown]
# # Arithmetic operators

# %%
print("5 + 2 =", 5+2)
print("5 - 2 =", 5-2)
print("5 * 2 =", 5*2)
print("5 / 2 =", 5/2)
print("5 // 2 =", 5//2)
print("5 ** 2 =", 5**2)
print("5 % 2 =", 5%2)
# Out:
# 5 + 2 = 7
# 5 - 2 = 3
# 5 * 2 = 10
# 5 / 2 = 2.5
# 5 // 2 = 2
# 5 ** 2 = 25
# 5 % 2 = 1

# %% [markdown]
# # Assignment operators

# %%
x = 5 # equivalent to x = 5
x += 5 # equivalent to x = x + 5
x -= 5 # equivalent to x = x - 5
x *= 5 # equivalent to x = x * 5
x /= 5 # equivalent to x = x / 5
x %= 5 # equivalent to x = x % 5
x //= 5 # equivalent to x = x // 5
x **= 5 # equivalent to x = x ** 5

# %% [markdown]
# # Comparison operators

# %%
num1 = 10
num2 = 5

print(num1, ">", num2, "=", num1 > num2) # greater than
print(num1, ">=", num2, "=", num1 >= num2) # greater or equal than
print(num1, "<", num2, "=", num1 < num2) # smaller than
print(num1, "<=", num2, "=", num1 <= num2) # smaller or equal than
print(num1, "==", num2, "=", num1 == num2) # equal to
print(num1, "!=", num2, "=", num1 != num2) # not equal to
# Out:
# 10 > 5 = True
# 10 >= 5 = True
# 10 < 5 = False
# 10 <= 5 = False
# 10 == 5 = False
# 10 != 5 = True

# %% [markdown]
# # Logical operators

# %%
print("True and True =", True and True)
print("True and False =", True and False)
print("False and True =", False and True)
print("False and False =", False and False)
# Out:
# True and True = True
# True and False = False
# False and True = False
# False and False = False

# %%
print(True and False and False)
# Out:
# False

# %%
print("True or True =", True or True)
print("True or False =", True or False)
print("False or True =", False or True)
print("False or False =", False or False)
# Out:
# True or True = True
# True or False = True
# False or True = True
# False or False = False

# %%
print("not True =", not True)
print("not False =", not False)
# Out:
# not True = False
# not False = True
